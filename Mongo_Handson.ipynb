# %%
from pymongo import MongoClient
import pprint
client = MongoClient('mongodb://localhost:27017/')
tesla_s = {
    "manufacturer" : 'Tesla Motors',
    "class" : "full-size",
    "body style" : '5-door liftback',
    'production' : [2012,2013],
    'model years' : [2013],
    'layout' : ['Rear-motor','rear-wheel drive'],
    'designer' : {
        'firstname' : 'Franz',
        'surname' : 'von Holzhausen'
    },
    "assembly" : [
        {
            'country' : 'United States',
            'city' : 'Fremont',
            'state' : 'california'
        },
        {
            'country' : 'The Netherlands',
            'city' : 'Tilburg'
        }
    ]
    
}
db = client.examples
db.autos.insert_one(tesla_s)
for a in db.autos.find():
    pprint.pprint(a)
# Out:
# {'_id': ObjectId('5a50fa2bb6c97a479c22fe69'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fa3cb6c97a479c22fe6b'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fd3db6c97a479c22fe6d'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fd49b6c97a479c22fe6f'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fd4bb6c97a479c22fe71'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fd67b6c97a479c22fe74'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}
# {'_id': ObjectId('5a50fd6fb6c97a479c22fe76'),
#  'assembly': [{'city': 'Fremont',
#                'country': 'United States',
#                'state': 'california'},
#               {'city': 'Tilburg', 'country': 'The Netherlands'}],
#  'body style': '5-door liftback',
#  'class': 'full-size',
#  'designer': {'firstname': 'Franz', 'surname': 'von Holzhausen'},
#  'layout': ['Rear-motor', 'rear-wheel drive'],
#  'manufacturer': 'Tesla Motors',
#  'model years': [2013],
#  'production': [2012, 2013]}

# %%
"""
Your task is to complete the 'porsche_query' function and in particular the query
to find all autos where the manufacturer field matches "Porsche".
Please modify only 'porsche_query' function, as only that will be taken into account.

Your code will be run against a MongoDB instance that we have provided.
If you want to run this code locally on your machine,
you have to install MongoDB and download and insert the dataset.
For instructions related to MongoDB setup and datasets please see Course Materials at
the following link:
https://www.udacity.com/wiki/ud032
"""

def porsche_query():
    # Please fill in the query to find all autos manuafactured by Porsche.
    query = {"manufacturer":"Porsche"}
    return query


# Do not edit code below this line in the online code editor.
# Code here is for local use on your own computer.
def get_db(db_name):
    # For local use
    from pymongo import MongoClient
    client = MongoClient('localhost:27017')
    db = client[db_name]
    return db

def find_porsche(db, query):
    # For local use
    return db.autos.find(query)


if __name__ == "__main__":
    # For local use
    db = get_db('examples')
    query = porsche_query()
    results = find_porsche(db, query)

    print("Printing first 3 results\n")
    import pprint
    for car in results[:3]:
        pprint.pprint(car)
# Out:
# Printing first 3 results

# %% [raw]
# car
